# %% [markdown]
# # **List**

# %%
[2,4,5,6,5.778,'malay','True']

# %%
lst = [2,634,6,6,7,4,35,4]
lst
# Out:
# [2, 634, 6, 6, 7, 4, 35, 4]

# %%
type(lst)
# Out:
# list

# %% [markdown]
# # ***List method ***

# %%
lst.append(777)
lst
# Out:
# [2, 634, 6, 6, 7, 4, 35, 4, 777]

# %%
lst.append('Malay')
lst
# Out:
# [2, 634, 6, 6, 7, 4, 35, 4, 777, 'Malay']

# %%
lst.append([56,3435,334])
lst
# Out:
# [2, 634, 6, 6, 7, 4, 35, 4, 777, 'Malay', [56, 3435, 334]]

# %%
lst.extend([46,34324242,2424,45,24])
print(lst)
# Out:
# [2, 634, 6, 6, 7, 4, 35, 4, 777, 'Malay', [56, 3435, 334], 46, 34324242, 2424, 46, 34324242, 2424, 45, 24, 46, 34324242, 2424, 45, 24]

# %%
lst[0]
# Out:
# 2

# %%
lst.insert(1,'joshi')
print(lst)
# Out:
# [2, 'joshi', 'joshi', 634, 6, 6, 7, 4, 35, 4, 777, 'Malay', [56, 3435, 334], 46, 34324242, 2424, 46, 34324242, 2424, 45, 24, 46, 34324242, 2424, 45, 24]

# %%
lst.pop()
# Out:
# 24

# %%
print(lst)
# Out:
# [2, 'joshi', 'joshi', 634, 6, 6, 7, 4, 35, 4, 777, 'Malay', [56, 3435, 334], 46, 34324242, 2424, 46, 34324242, 2424, 45, 24, 46, 34324242, 2424, 45]

# %%
lst.pop(15)
print(lst)
# Out:
# [2, 'joshi', 'joshi', 634, 6, 6, 7, 4, 35, 4, 777, 'Malay', [56, 3435, 334], 46, 34324242, 46, 34324242, 2424, 45, 24, 46, 34324242, 2424, 45]

# %%
lst.remove('joshi')
print(lst)
# Out:
# [2, 'joshi', 634, 6, 6, 7, 4, 35, 4, 777, 'Malay', [56, 3435, 334], 46, 34324242, 46, 34324242, 2424, 45, 24, 46, 34324242, 2424, 45]

# %%
lst.remove('joshi')
print(lst)
# Out:
# [2, 634, 6, 6, 7, 4, 35, 4, 777, 'Malay', [56, 3435, 334], 46, 34324242, 46, 34324242, 2424, 45, 24, 46, 34324242, 2424, 45]

# %%
lst.reverse()
print(lst)
# Out:
# [45, 2424, 34324242, 46, 24, 45, 2424, 34324242, 46, 34324242, 46, [56, 3435, 334], 'Malay', 777, 4, 35, 4, 7, 6, 6, 634, 2]

# %%
lst.sort(reverse=True)
print(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-be0986f14496> in <cell line: 1>()
# ----> 1 lst.sort(reverse=True)
#       2 print(lst)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l = lst.copy()
l
# Out:
# [24,
#  45,
#  45,
#  46,
#  46,
#  46,
#  2424,
#  2424,
#  34324242,
#  34324242,
#  34324242,
#  [56, 3435, 334],
#  'Malay',
#  777,
#  634,
#  35,
#  7,
#  6,
#  6,
#  4,
#  4,
#  2]

# %%
lst.clear()
lst
# Out:
# []

# %%
l
# Out:
# [24,
#  45,
#  45,
#  46,
#  46,
#  46,
#  2424,
#  2424,
#  34324242,
#  34324242,
#  34324242,
#  [56, 3435, 334],
#  'Malay',
#  777,
#  634,
#  35,
#  7,
#  6,
#  6,
#  4,
#  4,
#  2]

# %%
lst.enumerate(l)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-25505b100b5a> in <cell line: 1>()
# ----> 1 lst.enumerate(l)
#
# AttributeError: 'list' object has no attribute 'enumerate'

# %% [markdown]
# # ***New Section***
# # **Tuples**

# %%
tup = (34,54,46,23,42)
tup
# Out:
# (34, 54, 46, 23, 42)

# %%
type(tup)
# Out:
# tuple

# %%
tup.append(3)
tup
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-f2bc7f9a074d> in <cell line: 1>()
# ----> 1 tup.append(3)
#       2 tup
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tup.insert(2, 'abxc')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-8e5b179ff0e2> in <cell line: 1>()
# ----> 1 tup.insert(2, 'abxc')
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
tup.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-7018e2630ae7> in <cell line: 1>()
# ----> 1 tup.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
tup.remove(42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-aca4041c0fd5> in <cell line: 1>()
# ----> 1 tup.remove(42)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
tup.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-c148e5b31b96> in <cell line: 1>()
# ----> 1 tup.sort()
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
tup
# Out:
# (34, 54, 46, 23, 42)

# %%
tup.index(42)
# Out:
# 4

# %%
tup.count(4)
# Out:
# 0

# %% [markdown]
# # **Dictionary **

# %%
d = {'fruits' : 'Apple', 'Quantity': 5 }
d
# Out:
# {'fruits': 'Apple', 'Quantity': 5}

# %%
type(d)
# Out:
# dict

# %%
d = {

     'fruits': ['apple', 'Mango','orange'],
     'Quantity': [5,6,3]
}

d
# Out:
# {'fruits': ['apple', 'Mango', 'orange'], 'Quantity': [5, 6, 3]}

# %%
d.keys()
# Out:
# dict_keys(['fruits', 'Quantity'])

# %%
d.values()
# Out:
# dict_values([['apple', 'Mango', 'orange'], [5, 6, 3]])

# %%
d.items()
# Out:
# dict_items([('fruits', ['apple', 'Mango', 'orange']), ('Quantity', [5, 6, 3])])

# %%
d['fruits']
# Out:
# ['apple', 'Mango', 'orange']

# %%
d['Quantity']
# Out:
# [5, 6, 3]

# %%
d['fruits'].append('kiwi')
d
# Out:
# {'fruits': ['kiwi', 'kiwi', 'kiwi', 'kiwi'], 'Quantity': [5, 6, 3]}

# %%
d['Quantity'].append(4)
d
# Out:
# {'fruits': ['kiwi', 'kiwi', 'kiwi', 'kiwi'], 'Quantity': [5, 6, 3, 4, 4]}

# %%
d['fruits'].remove('kiwi')
d
# Out:
# {'fruits': ['kiwi', 'kiwi'], 'Quantity': [5, 6, 3, 4, 4]}

# %% [markdown]
# Set

# %%
s = {2,56,67,45,67,89,90}
s
# Out:
# {2, 45, 56, 67, 89, 90}

# %%
type(s)
# Out:
# set

# %%
ss = set([34,123,35,424,34,53,12,3])
ss
# Out:
# {3, 12, 34, 35, 53, 123, 424}

# %%
type(ss)
# Out:
# set

# %%
s
# Out:
# {2, 45, 56, 67, 89, 90}

# %%
s.add(45)
s
# Out:
# {2, 45, 56, 67, 89, 90}

# %%
s.discard(89)
s
# Out:
# {2, 45, 56, 67, 90}

# %%
s.pop()
s
# Out:
# {45, 56, 67, 90}

# %%
s.pop()
s
# Out:
# {45, 56, 90}

# %%
s.remove(90)
s
# Out:
# {45, 56}

# %%
s1 = {45,67,34,23,73,2}
s2 = {64,89,90,78,45,21}

s1
# Out:
# {2, 23, 34, 45, 67, 73}

# %%
s2
# Out:
# {21, 45, 64, 78, 89, 90}

# %%
s1.union(s2)
# Out:
# {2, 21, 23, 34, 45, 64, 67, 73, 78, 89, 90}

# %%
s1.intersection(s2)
# Out:
# {45}

# %%
s1.update({8,1,'a',False,96,4})
s1
# Out:
# {1, 2, 23, 34, 4, 45, 67, 73, 8, 96, False, 'a'}

# %%
s1.remove([999,'a'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-cd885d68431c> in <cell line: 1>()
# ----> 1 s1.remove([999,'a'])
#
# TypeError: unhashable type: 'list'

# %%
s1
# Out:
# {1, 2, 23, 34, 4, 45, 67, 73, 8, 96, False, 'a'}

# %%
for i in s1:
  print(i)
# Out:
# 96
# 1
# 2
# 34
# 67
# False
# 4
# 8
# 73
# a
# 45
# 23

# %%
s =[]

for i in s1:
  if i not in [False , 99,'a']:
    s.append(i)

print(s)
s = set(s)
print(s)
# Out:
# [96, 1, 2, 34, 67, 4, 8, 73, 45, 23]
# {96, 1, 2, 67, 34, 4, 8, 73, 45, 23}

# %%
tup = (345,242,456,3,57,68,56,45,35,323,52,34,2,5252,234)
tup
# Out:
# (345, 242, 456, 3, 57, 68, 56, 45, 35, 323, 52, 34, 2, 5252, 234)

# %%
tuple(enumerate(tup))
# Out:
# ((0, 345),
#  (1, 242),
#  (2, 456),
#  (3, 3),
#  (4, 57),
#  (5, 68),
#  (6, 56),
#  (7, 45),
#  (8, 35),
#  (9, 323),
#  (10, 52),
#  (11, 34),
#  (12, 2),
#  (13, 5252),
#  (14, 234))

# %%
list(enumerate(tup))
# Out:
# [(0, 345),
#  (1, 242),
#  (2, 456),
#  (3, 3),
#  (4, 57),
#  (5, 68),
#  (6, 56),
#  (7, 45),
#  (8, 35),
#  (9, 323),
#  (10, 52),
#  (11, 34),
#  (12, 2),
#  (13, 5252),
#  (14, 234)]
