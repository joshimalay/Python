# %%
a =45
print(a)
# Out:
# 45

# %% [markdown]
# Arithmetic Operators

# %%
a =5
b = 6
c = a + b
c
# Out:
# 11

# %%
a =5
b = 6
c = a - b
c
# Out:
# -1

# %%
a =5
b = 6
c = a * b
c
# Out:
# 30

# %%
a =5
b = 6
c = a / b
c
# Out:
# 0.8333333333333334

# %% [markdown]
# # Comparison operator

# %%
a = 10

a
# Out:
# 10

# %%
a == 15
# Out:
# False

# %%
a = 20

if a== 20:
  print("True")

else:
  print("False")
# Out:
# True

# %%
a = 20

if a != 20:
  print("True")

else:
  print("False")
# Out:
# False

# %%
a = 20

if a  <=   20:
  print("True")

else:
  print("False")
# Out:
# True

# %%
a = 15

if a  >= 20:
  print("True")

else:
  print("False")
# Out:
# False

# %% [markdown]
# Logical operator

# %%
x =-4
y =67
z =45


if x>0 and y == 0 and z>=34:
  print("True")

else:
  print("False")
# Out:
# False

# %%
a =9
if a%3 ==0:
  print('True')
else:
  print('False')
# Out:
# True

# %%
  a =9
if not(a%3 ==0):
 print('True')
else:
 print('False')
# Out:
# False

# %%
a =9
if not(a%5 ==0):
  print('True')
else:
  print('False')
# Out:
# True

# %%
a =15
if not(a%3==0and a%4==0):
  print('True')
else:
  print('False')
# Out:
# True

# %%
a  = 15
a%3 == 0
# Out:
# True

# %% [markdown]
# Assignments operator

# %%
x =6
x
# Out:
# 6

# %%
 x =6
 x +=1  # x = x + 1
 x
# Out:
# 7

# %%
x =6
x -=1  # x= x - 1
x
# Out:
# 5

# %%
x =6
x *=2
x
# Out:
# 12

# %%
x =6
x /=2
x
# Out:
# 3.0

# %%
x =6
x //=2
x
# Out:
# 3

# %%
x =6
x **=3
x
# Out:
# 216

# %% [markdown]
# Membership operator

# %%
x =45
y = 67

lst = [34,56,67,89,45]

if x not in lst:
  print("True")
else:
  print('False')

if y not in lst:
  print("True")
else:
  print('False')
# Out:
# False
# False

# %%
x =45
y = 67

lst = [34,56,67,89,45]

if x  in lst:
  print("True")
else:
  print('False')

if y  in lst:
  print("True")
else:
  print('False')
# Out:
# True
# True

# %% [markdown]
# Identity operators

# %%
a =5
b =7
print(a is b)
# Out:
# False

# %%
a =5
b =5
print(a is b)
# Out:
# True

# %%
a =5
b =7
print(a is not b)
# Out:
# True

# %%
a =5
b =5
print(a is not b)
# Out:
# False
