# %%
! pip install pandas

# %%
import pandas as pd

# %%
lst  = [45,67,5,45,3]
lst
# Out:
# [45, 67, 5, 45, 3]

# %% [markdown]
# # **Series**

# %%
ser = pd.Series([45, 67, 5, 45, 3])
ser
# Out:
# 0    45
# 1    67
# 2     5
# 3    45
# 4     3
# dtype: int64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser = pd.Series([45, 67, 5, 45, 3] , index=['a' , 'b' , 'c' , 'd' , 'e'])
ser
# Out:
# a    45
# b    67
# c     5
# d    45
# e     3
# dtype: int64

# %%
ser = pd.Series([45, 67, 5, 45, 3] , index=['a' , 'b' , 'c' , 'd' , 'e'] , name = 'age')
ser
# Out:
# a    45
# b    67
# c     5
# d    45
# e     3
# Name: age, dtype: int64

# %% [markdown]
# Data frame

# %%
# using list

# %%
lst_of_lst = [['apple',8],['mango',9],["banana" , 89]]
lst_of_lst
# Out:
# [['apple', 8], ['mango', 9], ['banana', 89]]

# %%
lst_of_lst[1]
# Out:
# ['mango', 9]

# %%
lst_of_lst[0][1]
# Out:
# 8

# %%
lst_of_lst = [['apple',8],['mango',9],["banana" , 89]]
df = pd.DataFrame(lst_of_lst)
df
# Out:
#         0   1
# 0   apple   8
# 1   mango   9
# 2  banana  89

# %%
lst_of_lst = [['apple',8],['mango',9],["banana" , 89]]
df = pd.DataFrame(lst_of_lst , columns=['Fruits' , 'Quantity'])
df
# Out:
#    Fruits  Quantity
# 0   apple         8
# 1   mango         9
# 2  banana        89

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
lst_of_lst = [['apple',8],['mango',9],["banana" , 89] , ['oranges ',89]]
df = pd.DataFrame(lst_of_lst , columns=['Fruits' , 'Quantity'])
df
# Out:
#      Fruits  Quantity
# 0     apple         8
# 1     mango         9
# 2    banana        89
# 3  oranges         89

# %%
lst_of_lst = [['apple',8 , 'D'],['mango',9 , 'L'],["banana" , 89 , 'D'] , ['oranges ',89 , 'd']]
df = pd.DataFrame(lst_of_lst , columns=['Fruits' , 'Quantity','Like/Dislike'])
df
# Out:
#      Fruits  Quantity Like/Dislike
# 0     apple         8            D
# 1     mango         9            L
# 2    banana        89            D
# 3  oranges         89            d

# %%
# using Dictionary

# %%
d= {

    'Fruits': ['apple','banana','mango','orange'],
    'Quantity':[8,9,89,89]
}
d
# Out:
# {'Fruits': ['apple', 'banana', 'mango', 'orange'], 'Quantity': [8, 9, 89, 89]}

# %%
d= {

    'Fruits': ['apple','banana','mango','orange'],
    'Quantity':[8,9,89,89]
}
df = pd.DataFrame(d)
df
# Out:
#    Fruits  Quantity
# 0   apple         8
# 1  banana         9
# 2   mango        89
# 3  orange        89

# %%
df['Fruits']
# Out:
# 0     apple
# 1    banana
# 2     mango
# 3    orange
# Name: Fruits, dtype: object

# %%
df['Quantity']
# Out:
# 0     8
# 1     9
# 2    89
# 3    89
# Name: Quantity, dtype: int64

# %%
df['Like/Dislike'] = ['D' , 'L' , 'D' , 'L']
df
# Out:
#    Fruits  Quantity Like/Dislike
# 0   apple         8            D
# 1  banana         9            L
# 2   mango        89            D
# 3  orange        89            L

# %%
# Arithmetic Operators

# %%
data = pd.DataFrame({'A':[1,23,4,5,6] , 'B' :[45,67,56,45,34] })
data
# Out:
#     A   B
# 0   1  45
# 1  23  67
# 2   4  56
# 3   5  45
# 4   6  34

# %%
data['A']
# Out:
# 0     1
# 1    23
# 2     4
# 3     5
# 4     6
# Name: A, dtype: int64

# %%
data['c'] = [56,78,67,90,100]
data
# Out:
#     A   B    c
# 0   1  45   56
# 1  23  67   78
# 2   4  56   67
# 3   5  45   90
# 4   6  34  100

# %%
data['c']
# Out:
# 0     56
# 1     78
# 2     67
# 3     90
# 4    100
# Name: c, dtype: int64

# %%
data['D'] = data['A'] * data["B"]
data
# Out:
#     A   B    c     D
# 0   1  45   56    45
# 1  23  67   78  1541
# 2   4  56   67   224
# 3   5  45   90   225
# 4   6  34  100   204

# %%
# Insert  And Delate

# %%
data
# Out:
#     A   B    c     D
# 0   1  45   56    45
# 1  23  67   78  1541
# 2   4  56   67   224
# 3   5  45   90   225
# 4   6  34  100   204

# %%
data.insert(1, 'Alphabets',['a' ,'b','c','d','e'])
data
# Out:
#     A Alphabets   B    c     D
# 0   1         a  45   56    45
# 1  23         b  67   78  1541
# 2   4         c  56   67   224
# 3   5         d  45   90   225
# 4   6         e  34  100   204

# %%
# Delete

del data['D']
data
# Out:
#     A Alphabets   B    c
# 0   1         a  45   56
# 1  23         b  67   78
# 2   4         c  56   67
# 3   5         d  45   90
# 4   6         e  34  100

# %%
del data['Alphabets']
data
# Out:
#     A   B    c
# 0   1  45   56
# 1  23  67   78
# 2   4  56   67
# 3   5  45   90
# 4   6  34  100

# %%
d = data.copy()
d
# Out:
#     A   B    c
# 0   1  45   56
# 1  23  67   78
# 2   4  56   67
# 3   5  45   90
# 4   6  34  100

# %%
del data

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-c5d84736ba45> in <cell line: 1>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
d
# Out:
#     A   B    c
# 0   1  45   56
# 1  23  67   78
# 2   4  56   67
# 3   5  45   90
# 4   6  34  100

# %%
{
    'A':[1,23,4,5,6] ,
    'B' :[45,67,56,45,34]

}
d1
# Out:
#     A   B
# 0   1  45
# 1  23  67
# 2   4  56
# 3   5  45
# 4   6  34

# %%
# load the data

# %%
import Cost_of_Living_Index_by_Country_2024.csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-50-a92e2288fe7e> in <cell line: 1>()
# ----> 1 import Cost_of_Living_Index_by_Country_2024.csv
#
# ModuleNotFoundError: No module named 'Cost_of_Living_Index_by_Country_2024'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df  = pd.read_csv('Cost_of_Living_Index_by_Country_2024.csv' , nrows = 5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-9a0c60d5a6a3> in <cell line: 1>()
# ----> 1 df  = pd.read_csv('Cost_of_Living_Index_by_Country_2024.csv' , nrows = 5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Copy of Cost_of_Living_Index_by_Country_2024.csv' , nrows = 10)
df
# Out:
#    Rank            Country  Cost of Living Index  Rent Index  \
# 0     1        Switzerland                 101.1        46.5
# 1     2            Bahamas                  85.0        36.7
# 2     3            Iceland                  83.0        39.2
# 3     4          Singapore                  76.7        67.2
# 4     5           Barbados                  76.6        19.0
# 5     6             Norway                  76.0        26.2
# 6     7            Denmark                  72.3        26.4
# 7     8  Hong Kong (China)                  70.8        59.4
# 8     9      United States                  70.4        41.7
# 9    10          Australia                  70.2        33.4
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            74.9            109.1                    97.0
# 1                            61.8             81.6                    83.3
# ...

# %%
df  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Copy of Cost_of_Living_Index_by_Country_2024.csv' , nrows = 10 ,usecols = ['Country' , 'Groceries Index'])
df
# Out:
#              Country  Groceries Index
# 0        Switzerland            109.1
# 1            Bahamas             81.6
# 2            Iceland             88.4
# 3          Singapore             74.6
# 4           Barbados             80.8
# 5             Norway             79.0
# 6            Denmark             64.8
# 7  Hong Kong (China)             84.6
# 8      United States             75.0
# 9          Australia             77.3
